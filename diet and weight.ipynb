# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression

df =pd.read_csv('food_coded.csv')

df.head
df.tail
df.shape
# Out:
# (125, 61)

# %%
#Relationship between weight and diet habit
#independent variables are below: 11) cook-how often do you cook?; 12) cuisine-what type of cuisine did you eat growing up?
#18) eating_changes_coded1; 19) eating out-frequency of eating out in a typical week; 
#26) fav_cuisine_coded; 27) fav_food-was your favorite food cooked at home or store brought?;
#30) fruit day-how likely to eat fruit in a regular day; 36) Ideal_diet_coded; 45) nutritional_check-checking nutritional values frequency; 
#57) veggies_day-how likely to eat veggies in a day?. 
#In total, there are all 10 variables as the predictive variables.

# %%
# df.columns[[11,12,18,19,26,27,30,36,45,57]]
Xname = ['cook', 'cuisine', 'eating_changes_coded1',\
       'eating_out', 'fav_cuisine_coded', 'fav_food', 'fruit_day',\
       'ideal_diet_coded', 'nutritional_check', 'veggies_day']

df.columns[[33]]
Yname = ['weight']
X = df.loc[:,Xname]
Y = df.loc[:,Yname]
X = X.apply(pd.to_numeric, errors="ignore")
Y = Y.apply(pd.to_numeric, errors="ignore")
X.loc[13,'eating_out'] = 1
# clf = DecisionTreeClassifier()
# clf.fit(X.values,Y.values)
# predicted = clf.predict(X)

fig = plt.figure()  
ax1 = fig.add_subplot(111)
ax1.set_title('Scatter Plot')  
ax1.scatter(X.iloc[:,0],Y.iloc[:,0],label='3')
plt.xlabel(Xname[0])
plt.ylabel(Yname)
plt.show()


fig = plt.figure()  
ax1 = fig.add_subplot(111)
ax1.set_title('Scatter Plot')  
ax1.scatter(X.iloc[:,1],Y.iloc[:,0],label='3')
plt.xlabel(Xname[1])
plt.ylabel(Yname)
plt.show()


fig = plt.figure()  
ax1 = fig.add_subplot(111)
ax1.set_title('Scatter Plot')  
ax1.scatter(X.iloc[:,2],Y.iloc[:,0],label='3')
plt.xlabel(Xname[2])
plt.ylabel(Yname)
plt.show()


fig = plt.figure()  
ax1 = fig.add_subplot(111)
ax1.set_title('Scatter Plot')  
ax1.scatter(X.iloc[:,3],Y.iloc[:,0],label='3')
plt.xlabel(Xname[3])
plt.ylabel(Yname)
plt.show()


fig = plt.figure()  
ax1 = fig.add_subplot(111)
ax1.set_title('Scatter Plot')  
ax1.scatter(X.iloc[:,4],Y.iloc[:,0],label='3')
plt.xlabel(Xname[4])
plt.ylabel(Yname)
plt.show()


fig = plt.figure()  
ax1 = fig.add_subplot(111)
ax1.set_title('Scatter Plot')  
ax1.scatter(X.iloc[:,5],Y.iloc[:,0],label='3')
plt.xlabel(Xname[5])
plt.ylabel(Yname)
plt.show()

# %%
#we plot the all scatter graphs of the weight and the independent variables.
#weight and cook frequency have a slight inverse relationship. But people weight most are not those who cook every day, but who that cook a couple of times a week.
#We know the Italian/Franch/greek and Asian/chineses/thai/Nepal are more popular, but there is an obvious difference , which is that Asian/Chineses/thai/Nepal will bring lower weight, maybe indicating that they are more healthy.

# %%
fig = plt.figure()  
ax1 = fig.add_subplot(111)
ax1.set_title('Scatter Plot')  
ax1.scatter(X.iloc[:,7],Y.iloc[:,0],label='3')
plt.xlabel(Xname[7])
plt.ylabel(Yname)
plt.show()

fig = plt.figure()  
ax1 = fig.add_subplot(111)
ax1.set_title('Scatter Plot')  
ax1.scatter(X.iloc[:,8],Y.iloc[:,0],label='3')
plt.xlabel(Xname[8])
plt.ylabel(Yname)
plt.show()


fig = plt.figure()  
ax1 = fig.add_subplot(111)
ax1.set_title('Scatter Plot')  
ax1.scatter(X.iloc[:,9],Y.iloc[:,0],label='3')
plt.xlabel(Xname[9])
plt.ylabel(Yname)
plt.show()

fig = plt.figure()  
ax1 = fig.add_subplot(111)
ax1.set_title('Scatter Plot')  
ax1.scatter(X.iloc[:,6],Y.iloc[:,0],label='3')
plt.xlabel(Xname[6])
plt.ylabel(Yname)
plt.show()

# %%
#As for fruit day, we get that all most people likely and more to eat fruit in a regular day. Now, people tend to add veggies, eat healthier food and add fruit, referring to that people are pay more attend to healthy diet.
#

# %%
#With the random sampling method, we split all independent and response variables into two part, one for train, which have 93 records
#and the other for test, which have 32 records, used to test the fitting of the model.

X_train,X_test, y_train, y_test = train_test_split(X, Y, random_state=1)  
print(X_train.shape)  
print(y_train.shape) 
print(X_test.shape)
print(y_test.shape) 
linreg = LinearRegression()  
model=linreg.fit(X_train, y_train) 
print(model)
print(linreg.intercept_)
print(linreg.coef_)
y_pred = linreg.predict(X_test)  
print(y_pred)
plt.scatter(y_test,y_pred)
print(type(y_pred),type(y_test))
print(len(y_pred),len(y_test))
print(y_pred.shape,y_test.shape)
from sklearn import metrics  
import numpy as np  
sum_mean=0  
for i in range(len(y_pred)):  
    sum_mean+=(y_pred[i]-y_test.values[i])**2  
sum_erro=np.sqrt(sum_mean/50)  
# calculate RMSE by hand
print("RMSE by hand:",sum_erro)

plt.figure()  
plt.plot(range(len(y_pred)),y_pred,'b',label="predict")  
plt.plot(range(len(y_pred)),y_test,'r',label="test")  
plt.legend(loc="upper right") # 
plt.xlabel("Xvariables")  
plt.ylabel('Weight')  
plt.show()  

#We fit all the independent variables to dependent variable and get the results: the intercept is 168 and the slop for the ten explainable variables are listed below. 
#We can quantitatively and qualitatively know the correlation of weight with cook/cuisine and so on.
# Out:
# (93, 10)
# (93, 1)
# (32, 10)
# (32, 1)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# [ 168.60352858]
# [[ 2.27676413  1.97367847  1.38982472  2.75952307  0.55269763 -3.22593853
#   -1.69908757  2.20691594 -1.08995195 -6.47919307]]
# [[ 165.68101659]
#  [ 157.37261675]
#  [ 159.64478834]
#  [ 140.49154433]
#  [ 179.16263864]
#  [ 150.1401739 ]
#  [ 157.37649135]
#  [ 150.17913545]
#  [ 163.77194012]
#  [ 164.19240357]
#  [ 173.85647865]
#  [ 153.11436873]
#  [ 181.25822478]
#  [ 139.71954962]
#  [ 153.78682507]
#  [ 161.54680417]
#  [ 152.2502296 ]
#  [ 145.177519  ]
#  [ 157.27124825]
#  [ 145.35501505]
#  [ 159.4254775 ]
#  [ 174.14726531]
#  [ 168.52463753]
#  [ 153.54218816]
#  [ 161.71474208]
#  [ 157.80221406]
#  [ 156.36048887]
#  [ 145.62494074]
#  [ 156.05038479]
#  [ 150.26301275]
#  [ 158.08455537]
#  [ 149.12064257]]
# <class 'numpy.ndarray'> <class 'pandas.core.frame.DataFrame'>
# 32 32
# (32, 1) (32, 1)
# RMSE by hand: [ 33.76613744]
